# %%
import os
import easyocr
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image, ImageDraw

from deepface import DeepFace
import matplotlib.pyplot as plt

os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

image_1 = '../pictures/ivan_ktp.jpg'
image_2 = '../pictures/ivan_selfie.jpg'


# Models for Verify Image --------------------------
models = [
  "VGG-Face", 
  "Facenet", 
  "Facenet512", 
  "OpenFace", 
  "DeepFace", 
  "DeepID", 
  "ArcFace", 
  "Dlib", 
  "SFace",
]

backends = [
  'opencv', 
  'ssd', 
  'dlib', 
  'mtcnn', 
  'retinaface', 
  'mediapipe',
  'yolov8',
  'yunet',
  'fastmtcnn',
]

metrics = ["cosine", "euclidean", "euclidean_l2"]
#-------------------------------------------------

# %%
cd ../pictures/
# Out:
# c:\Users\IvanRivaldo\OneDrive - MOONLAY TECHNOLOGIES, PT\Documents\AI-NLP-Learn\computer_vision\pictures

# %%
# Code to get Text from image
reader = easyocr.Reader(['en'])

text_result = reader.readtext(image_1, detail=0, paragraph=False)
text_result

# %%
img1 = DeepFace.detectFace(image_1, detector_backend = backends[4])
img2 = DeepFace.detectFace(image_2, detector_backend = backends[4])
# Out:
# ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# ⚠️ Function detectFace is deprecated. Use extract_faces instead.

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
# Code to get Image Verify
validation = DeepFace.verify(img1_path = image_1, img2_path = image_2, model_name = models[6], detector_backend=backends[4])
validation
# Out:
# {'verified': True,
#  'distance': 0.475618462373147,
#  'threshold': 0.68,
#  'model': 'ArcFace',
#  'detector_backend': 'retinaface',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 527, 'y': 345, 'w': 98, 'h': 123},
#   'img2': {'x': 244, 'y': 406, 'w': 653, 'h': 918}},
#  'time': 12.7}
